# %% [markdown]
# '''# Q2 the main median | Q1 is the median for Q2 and the negative extreme | Q3 is the median between the main median Q2 and
# the extreme right value |
# Inter Quartile range IQR = Q3-Q1
# Outliers = Q3 + 1.5 IQR
# Outliers = Q1 - 1.5 IQR'''
# 'Image'
# http://www.statistics4u.com/fundstat_eng/cc_iqr.html

# %% [markdown]
# n(Sumxy)-(sumx)(sumy)/ Whole.Sq.rt[n(sumx^2)-(sumx)^2][n(sumy^2)-(sumy)^2] #carl pearson's coeff of x and y

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df1= pd.read_csv('wine.csv')

# %%
df1
# Out:
#         Unnamed: 0      country  \
# 0                0        Italy
# 1                1     Portugal
# 2                2           US
# 3                3           US
# 4                4           US
# 5                5        Spain
# 6                6        Italy
# 7                7       France
# 8                8      Germany
# 9                9       France
# 10              10           US
# 11              11       France
# 12              12           US
# 13              13        Italy
# 14              14           US
# 15              15      Germany
# 16              16    Argentina
# 17              17    Argentina
# 18              18        Spain
# 19              19           US
# 20              20           US
# 21              21           US
# 22              22        Italy
# 23              23           US
# 24              24        Italy
# 25              25           US
# 26              26        Italy
# 27              27        Italy
# ...

# %%
plt.plot(df1['Unnamed: 0'],df1['price'])
plt.subplots(figsize=20)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-f7cd1ea544e6> in <module>
#       1 plt.plot(df1['Unnamed: 0'],df1['price'])
# ----> 2 plt.subplots(figsize=20)
#       3 plt.show()
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in subplots(nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw, **fig_kw)
#    1215
#    1216     """
# -> 1217     fig = figure(**fig_kw)
#    1218     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1219                        squeeze=squeeze, subplot_kw=subplot_kw,
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#     523                                         frameon=frameon,
#     524                                         FigureClass=FigureClass,
# ...
